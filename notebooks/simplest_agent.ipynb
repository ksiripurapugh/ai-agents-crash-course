# %% [markdown]
# # Creating a Simple Agent with Tracing

# %%
import dotenv
import os

from openai import OpenAI

dotenv.load_dotenv()

if not os.environ.get("OPENAI_API_KEY"):
    print(
        """Error: OPENAI_API_KEY environment variable not set. Please copy the .env.template file as .env and fill it in.
    
    You can execute these commands in the terminal to get started:
    cp .env.template .env
    code .env
    """
    )

# Test OpenAI Access
print(
    OpenAI()
    .responses.create(
        model=os.environ["OPENAI_DEFAULT_MODEL"], input="Say: We are up and running!"
    )
    .output_text
)
# Out:
# We are up and running!

# %%
from agents import Agent, Runner, trace
from openai.types.responses import ResponseTextDeltaEvent

# %% [markdown]
# Create a simple Nutrition Assistant Agent

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    You are a helpful assistant giving out nutrition advice.
    You give concise answers.
    """,
)

# %% [markdown]
# Let's execute the Agent:

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(nutrition_agent, "How healthy are bananas?")

print(result)
# Out:
# RunResult:
# - Last agent: Agent(name="Nutrition Assistant", ...)
# - Final output (str):
#     Bananas are generally healthy and convenient.
#
#     Key benefits:
#     - Good potassium (helps blood pressure)
#     - Vitamin B6 and vitamin C
#     - Dietary fiber (supports digestion)
#     - Quick, portable energy (natural sugars)
#
#     Approximate: 100 calories per medium banana; about 3 g fiber and 14 g sugars.
#
#     Things to consider:
#     - Moderation with diabetes or strict sugar goals; portion size matters.
#     - Choose ripe/firmness based on your preference; ripe bananas are sweeter and softer.
#
#     Bottom line: a nutritious, filling fruit that fits well in most balanced diets.
# - 2 new item(s)
# - 1 raw response(s)
# - 0 input guardrail result(s)
# - 0 output guardrail result(s)
# (See `RunResult` for more details)

# %% [markdown]
# Streaming the answer to the screen, token by token

# %%
response_stream = Runner.run_streamed(nutrition_agent, "How healthy are bananas?")

async for event in response_stream.stream_events():
    if event.type == "raw_response_event" and isinstance(
        event.data, ResponseTextDeltaEvent
    ):
        print(event.data.delta, end="", flush=True)
# Out:
# Generally healthy as part of a balanced diet.
#
# Key points:
# - Nutrients: good source of potassium, vitamin B6, vitamin C, and fiber.
# - Calories/sugar: about 100–105 calories per medium banana; contains natural sugars.
# - Glycemic impact: moderate; ripe bananas are sweeter (slightly higher sugar) but still fine for most people.
# - Kiwi factors: low fat, portable, convenient snack; can support energy before/after workouts.
# - Considerations: people with kidney issues should monitor potassium; if you’re watching sugar intake, factor in fruit portions.
#
# Bottom line: bananas are a nutritious, convenient fruit that fit well in most diets.

# %% [markdown]
# _Good Job!_
